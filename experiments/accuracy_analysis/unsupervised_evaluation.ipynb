# %% [markdown]
# # Unsupervised Experiment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle, islice

from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# Set up methods' colors
methods_colors = {
    "oracle": "#70FF00",
    "avg_ens": "#FF7133", #FF7133 -> FF9664 (lighter)
    "best_ms": "#33D4FF",
    "detectors": "#CCCCCC",
    "feature_based": "#91AAC2",
    "sit": "#FFB522",
    "conv": "#4494FF",
    "conv_2": "#0048FF",
    "rocket": "#EA7DFF", #B400FF -> D800FF -> EA7DFF(lighter)
    "best_ad_train": "#228B22",
    "worst_ad_test": "#8B0000",
}

# %% [markdown]
# # Get results data
#
# Please select a measure for the analysis. You can choose between VUS_PR and AUC_PR.

# %%
measure_name = 'VUS_PR'
test_size = 1

# Uncomment this command and all plt.savefig(...) commands to save the generated figures
# figure_path = 'dummy/path/{}.svg'

all_method_score = [
    'convnet_128_score',
    'resnet_1024_score',
    'sit_stem_512_score',
    'rocket_128_score',
    'knn_1024_score',
    'Avg Ens',
]

all_method_score_name = [
    'convnet',
    'resnet',
    'sit_stem',
    'rocket',
    'knn',
    'Avg Ens',
]

# %%
def read_df(measure_name,test_size,split_number):
    df = pd.read_csv('../../results/unsupervised_results/{}/current_testsize_{}_split_{}.csv'.format(measure_name,test_size,split_number))
    df = df.rename(columns={'Unnamed: 0':'filename'})
    df = df.set_index('filename')
    df.head()
    return df

# %%
all_length = [16, 32, 64, 128, 256, 512, 768, 1024]

template_names = {
    'inception_time_{}': 'InceptTime-{}',
    'convnet_{}': 'ConvNet-{}',
    'resnet_{}': 'ResNet-{}',
    'sit_conv_{}': 'SiT-conv-{}',
    'sit_linear_{}': 'SiT-linear-{}',
    'sit_stem_{}': 'SiT-stem-{}',
    'sit_stem_relu_{}': 'SiT-stem-ReLU-{}',
    'rocket_{}': 'Rocket-{}',
    'ada_boost_{}': 'AdaBoost-{}',
    'knn_{}': 'kNN-{}',
    'decision_tree_{}': 'DecisionTree-{}',
    'random_forest_{}': 'RandomForest-{}',
    'mlp_{}': 'MLP-{}',
    'bayes_{}': 'Bayes-{}',
    'qda_{}': 'QDA-{}',
    'svc_linear_{}': 'SVC-{}',
    'IFOREST': 'IForest',
    'LOF': 'LOF',
    'MP': 'MP',
    'NORMA': 'NormA',
    'IFOREST1': 'IForest1',
    'HBOS': 'HBOS',
    'OCSVM': 'OCSVM',
    'PCA': 'PCA',
    'AE': 'AE',
    'CNN': 'CNN',
    'LSTM': 'LSTM',
    'POLY': 'POLY',
    'Avg Ens': 'Avg Ens',
    'Oracle': 'Oracle',
    'best_ms': 'Best MS',
    'VUS_PR': 'VUS-PR',
    'label': 'Label',
    'best_ms': 'Best MS',
    'convnet': "ConvNet",
    'resnet': "ResNet",
    'rocket': "Rocket",
    'knn': "kNN",
    'sit_stem': "SiT-stem",
    'AUC_PR': 'AUC PR'
}

final_names = {}
for length in all_length:
    for key, value in template_names.items():
        if '{}' in key:
            new_key = key.format(length)
            new_value = value.format(length)
            final_names[new_key] = new_value
        else:
            final_names[key] = value

# %% [markdown]
# ## Overall results

# %%
all_dataset = []
all_methods = None
curr_names = [
    'Avg Ens', 
    'convnet', 
    'resnet', 
    'sit_stem', 
    'knn', 
    'rocket'
]

for split_number in range(16):
    df = read_df(measure_name, test_size, split_number)
    print(df)
    all_dataset.append(df.index[0].split('/')[0])
    all_methods = list(df[all_method_score + ['Oracle', 'best_ad_train', 'worst_ad_test']].mean().index)

df_transfer_res = pd.DataFrame(index=all_dataset, columns=all_methods)
for split_number in range(16):
    df = read_df(measure_name, test_size, split_number)
    for method in all_methods:
        df_transfer_res.at[df.index[0].split('/')[0], method] = df[method].mean()

df_to_plot = df_transfer_res[all_method_score].subtract(df_transfer_res['worst_ad_test'], axis=0).div(df_transfer_res['Oracle'] - df_transfer_res['worst_ad_test'], axis=0)

order = list(df_to_plot.median().sort_values().index)[::-1]

plt.rcParams.update({'font.size': 16})

my_pal = {"Avg Ens": methods_colors["avg_ens"], "convnet_128_score": methods_colors["conv"], "resnet_1024_score": methods_colors["conv_2"], 'knn_1024_score': methods_colors["feature_based"], 'rocket_128_score': methods_colors["rocket"], 'sit_stem_512_score': methods_colors["sit"]}
names_graph = [final_names[x] for x in curr_names]

plt.figure(figsize=(4, 7))
sns.boxplot(df_to_plot, order=order, palette=my_pal, saturation=1)
plt.xticks(list(range(len(names_graph))), names_graph, rotation=45)
plt.ylim(0, 1)
plt.ylabel(r"$\overline{" + final_names[measure_name] + "}$")

plt.axhline(df_transfer_res['best_ad_train'].subtract(df_transfer_res['worst_ad_test'], axis=0).div(df_transfer_res['Oracle'] - df_transfer_res['worst_ad_test'], axis=0).mean(), linestyle='--', linewidth=2, color=methods_colors['best_ad_train'])

plt.tight_layout()
# plt.savefig(figure_path.format("11_one_vs_all_1"))
plt.show()
plt.close()
# Out:
#                                           label    Oracle   Avg Ens  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out       CNN  0.709755  0.778573
# YAHOO\YahooA3Benchmark-TS10_data.out        CNN  0.504933  0.401116
# YAHOO\YahooA3Benchmark-TS11_data.out       LSTM  0.637848  0.563309
# YAHOO\YahooA3Benchmark-TS12_data.out        CNN  0.653165  0.691579
# YAHOO\YahooA3Benchmark-TS13_data.out        CNN  0.526513  0.592225
# ...                                         ...       ...       ...
# YAHOO\Yahoo_A2synthetic_96_data.out         CNN  0.519939  0.017583
# YAHOO\Yahoo_A2synthetic_97_data.out         CNN  0.641742  0.658003
# YAHOO\Yahoo_A2synthetic_98_data.out        HBOS  0.718101  0.647950
# YAHOO\Yahoo_A2synthetic_99_data.out    IFOREST1  0.603465  0.006225
# YAHOO\Yahoo_A2synthetic_9_data.out          CNN  0.856541  0.700697
#
#                                        best_ad_train  average_ad_train  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out       0.526127          0.245704
# YAHOO\YahooA3Benchmark-TS10_data.out        0.454349          0.170847
# YAHOO\YahooA3Benchmark-TS11_data.out        0.456344          0.194496
# YAHOO\YahooA3Benchmark-TS12_data.out        0.395481          0.256444
# YAHOO\YahooA3Benchmark-TS13_data.out        0.387880          0.198631
# ...                                              ...               ...
# YAHOO\Yahoo_A2synthetic_96_data.out         0.008730          0.093934
# YAHOO\Yahoo_A2synthetic_97_data.out         0.443352          0.226782
# YAHOO\Yahoo_A2synthetic_98_data.out         0.140800          0.410417
# YAHOO\Yahoo_A2synthetic_99_data.out         0.004767          0.097906
# YAHOO\Yahoo_A2synthetic_9_data.out          0.856541          0.257080
#
#                                        worst_ad_train  best_ad_test  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out        0.709755      0.565401
# YAHOO\YahooA3Benchmark-TS10_data.out         0.200737      0.504933
# YAHOO\YahooA3Benchmark-TS11_data.out         0.637848      0.547137
# YAHOO\YahooA3Benchmark-TS12_data.out         0.653165      0.554532
# YAHOO\YahooA3Benchmark-TS13_data.out         0.526513      0.506547
# ...                                               ...           ...
# YAHOO\Yahoo_A2synthetic_96_data.out          0.518806      0.519939
# YAHOO\Yahoo_A2synthetic_97_data.out          0.594011      0.503128
# YAHOO\Yahoo_A2synthetic_98_data.out          0.616262      0.043093
# YAHOO\Yahoo_A2synthetic_99_data.out          0.019974      0.007725
# YAHOO\Yahoo_A2synthetic_9_data.out           0.519903      0.533921
#
#                                        average_ad_test  worst_ad_test  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out         0.245704       0.022285
# YAHOO\YahooA3Benchmark-TS10_data.out          0.170847       0.027564
# YAHOO\YahooA3Benchmark-TS11_data.out          0.194496       0.012289
# YAHOO\YahooA3Benchmark-TS12_data.out          0.256444       0.025494
# YAHOO\YahooA3Benchmark-TS13_data.out          0.198631       0.010019
# ...                                                ...            ...
# YAHOO\Yahoo_A2synthetic_96_data.out           0.093934       0.001148
# YAHOO\Yahoo_A2synthetic_97_data.out           0.226782       0.058060
# YAHOO\Yahoo_A2synthetic_98_data.out           0.410417       0.506484
# YAHOO\Yahoo_A2synthetic_99_data.out           0.097906       0.001682
# YAHOO\Yahoo_A2synthetic_9_data.out            0.257080       0.003390
#
#                                        convnet_128_score  ... knn_1024_inf  \
# filename                                                  ...
# YAHOO\YahooA3Benchmark-TS100_data.out           0.124778  ...     0.025110
# YAHOO\YahooA3Benchmark-TS10_data.out            0.228582  ...     0.026933
# YAHOO\YahooA3Benchmark-TS11_data.out            0.180128  ...     0.010619
# YAHOO\YahooA3Benchmark-TS12_data.out            0.205960  ...     0.023702
# YAHOO\YahooA3Benchmark-TS13_data.out            0.226426  ...     0.009674
# ...                                                  ...  ...          ...
# YAHOO\Yahoo_A2synthetic_96_data.out             0.002201  ...     0.025457
# YAHOO\Yahoo_A2synthetic_97_data.out             0.346554  ...     0.011145
# YAHOO\Yahoo_A2synthetic_98_data.out             0.342119  ...     0.010852
# YAHOO\Yahoo_A2synthetic_99_data.out             0.603465  ...     0.012457
# YAHOO\Yahoo_A2synthetic_9_data.out              0.603465  ...     0.011570
#
#                                        resnet_1024_score  resnet_1024_class  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out           0.133935                PCA
# YAHOO\YahooA3Benchmark-TS10_data.out            0.166062               POLY
# YAHOO\YahooA3Benchmark-TS11_data.out            0.039308                PCA
# YAHOO\YahooA3Benchmark-TS12_data.out            0.162368                PCA
# YAHOO\YahooA3Benchmark-TS13_data.out            0.026568                PCA
# ...                                                  ...                ...
# YAHOO\Yahoo_A2synthetic_96_data.out             0.002201               POLY
# YAHOO\Yahoo_A2synthetic_97_data.out             0.346554               POLY
# YAHOO\Yahoo_A2synthetic_98_data.out             0.665678            IFOREST
# YAHOO\Yahoo_A2synthetic_99_data.out             0.603465               POLY
# YAHOO\Yahoo_A2synthetic_9_data.out              0.603465               POLY
#
#                                       resnet_1024_inf  rocket_128_score  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out        0.003032          0.133935
# YAHOO\YahooA3Benchmark-TS10_data.out         0.002978          0.032082
# YAHOO\YahooA3Benchmark-TS11_data.out         0.002935          0.039308
# YAHOO\YahooA3Benchmark-TS12_data.out         0.003083          0.162368
# YAHOO\YahooA3Benchmark-TS13_data.out         0.005715          0.026568
# ...                                               ...               ...
# YAHOO\Yahoo_A2synthetic_96_data.out          0.004505          0.001486
# YAHOO\Yahoo_A2synthetic_97_data.out          0.002857          0.006827
# YAHOO\Yahoo_A2synthetic_98_data.out          0.004326          0.506484
# YAHOO\Yahoo_A2synthetic_99_data.out          0.002591          0.603465
# YAHOO\Yahoo_A2synthetic_9_data.out           0.005612          0.856541
#
#                                        rocket_128_class rocket_128_inf  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out               PCA       0.068105
# YAHOO\YahooA3Benchmark-TS10_data.out                PCA       0.068420
# YAHOO\YahooA3Benchmark-TS11_data.out                PCA       0.069022
# YAHOO\YahooA3Benchmark-TS12_data.out                PCA       0.068082
# YAHOO\YahooA3Benchmark-TS13_data.out                PCA       0.068995
# ...                                                 ...            ...
# YAHOO\Yahoo_A2synthetic_96_data.out             IFOREST       0.069147
# YAHOO\Yahoo_A2synthetic_97_data.out                 PCA       0.067429
# YAHOO\Yahoo_A2synthetic_98_data.out                  AE       0.068362
# YAHOO\Yahoo_A2synthetic_99_data.out                POLY       0.067858
# YAHOO\Yahoo_A2synthetic_9_data.out                NORMA       0.068039
#
#                                        sit_stem_512_score  sit_stem_512_class  \
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out            0.146451            IFOREST1
# YAHOO\YahooA3Benchmark-TS10_data.out             0.021937                HBOS
# YAHOO\YahooA3Benchmark-TS11_data.out             0.066709            IFOREST1
# YAHOO\YahooA3Benchmark-TS12_data.out             0.288953            IFOREST1
# YAHOO\YahooA3Benchmark-TS13_data.out             0.098042                POLY
# ...                                                   ...                 ...
# YAHOO\Yahoo_A2synthetic_96_data.out              0.002201                POLY
# YAHOO\Yahoo_A2synthetic_97_data.out              0.006596                HBOS
# YAHOO\Yahoo_A2synthetic_98_data.out              0.718101                HBOS
# YAHOO\Yahoo_A2synthetic_99_data.out              0.001605                HBOS
# YAHOO\Yahoo_A2synthetic_9_data.out               0.002306                HBOS
#
#                                       sit_stem_512_inf
# filename
# YAHOO\YahooA3Benchmark-TS100_data.out         0.010238
# YAHOO\YahooA3Benchmark-TS10_data.out          0.011093
# YAHOO\YahooA3Benchmark-TS11_data.out          0.010165
# YAHOO\YahooA3Benchmark-TS12_data.out          0.010807
# YAHOO\YahooA3Benchmark-TS13_data.out          0.011700
# ...                                                ...
# YAHOO\Yahoo_A2synthetic_96_data.out           0.009612
# YAHOO\Yahoo_A2synthetic_97_data.out           0.010816
# YAHOO\Yahoo_A2synthetic_98_data.out           0.013741
# YAHOO\Yahoo_A2synthetic_99_data.out           0.011287
# YAHOO\Yahoo_A2synthetic_9_data.out            0.014041
#
# [362 rows x 24 columns]
#                                              label    Oracle   Avg Ens  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out  IFOREST  0.800735  0.780073
# Occupancy\room-occupancy-0.test.csv@2.out  IFOREST  0.639187  0.693833
# Occupancy\room-occupancy-0.test.csv@3.out      PCA  0.946366  0.895603
# Occupancy\room-occupancy-0.test.csv@4.out  IFOREST  0.843467  0.838815
# Occupancy\room-occupancy-0.test.csv@5.out  IFOREST  0.822383  0.833145
# Occupancy\room-occupancy-1.test.csv@3.out      PCA  0.889171  0.723232
# Occupancy\room-occupancy-1.test.csv@4.out    OCSVM  0.433444  0.314194
# Occupancy\room-occupancy.train.csv@3.out       PCA  0.896979  0.842502
# Occupancy\room-occupancy.train.csv@4.out      HBOS  0.778941  0.807090
# Occupancy\room-occupancy.train.csv@5.out      POLY  0.727351  0.587458
#
#                                            best_ad_train  average_ad_train  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out       0.473558          0.583770
# Occupancy\room-occupancy-0.test.csv@2.out       0.408220          0.533605
# Occupancy\room-occupancy-0.test.csv@3.out       0.919851          0.647714
# Occupancy\room-occupancy-0.test.csv@4.out       0.379201          0.608732
# Occupancy\room-occupancy-0.test.csv@5.out       0.584146          0.621392
# Occupancy\room-occupancy-1.test.csv@3.out       0.151197          0.456739
# Occupancy\room-occupancy-1.test.csv@4.out       0.157848          0.278404
# Occupancy\room-occupancy.train.csv@3.out        0.167260          0.528567
# Occupancy\room-occupancy.train.csv@4.out        0.330617          0.490911
# Occupancy\room-occupancy.train.csv@5.out        0.158154          0.356702
#
#                                            worst_ad_train  best_ad_test  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out        0.618928      0.741771
# Occupancy\room-occupancy-0.test.csv@2.out        0.552450      0.639187
# Occupancy\room-occupancy-0.test.csv@3.out        0.242522      0.928389
# Occupancy\room-occupancy-0.test.csv@4.out        0.738565      0.777587
# Occupancy\room-occupancy-0.test.csv@5.out        0.685634      0.723566
# Occupancy\room-occupancy-1.test.csv@3.out        0.191909      0.802624
# Occupancy\room-occupancy-1.test.csv@4.out        0.398055      0.349598
# Occupancy\room-occupancy.train.csv@3.out         0.723578      0.796779
# Occupancy\room-occupancy.train.csv@4.out         0.577636      0.778941
# Occupancy\room-occupancy.train.csv@5.out         0.410643      0.380780
#
#                                            average_ad_test  worst_ad_test  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out         0.583770       0.256385
# Occupancy\room-occupancy-0.test.csv@2.out         0.533605       0.345203
# Occupancy\room-occupancy-0.test.csv@3.out         0.647714       0.230645
# Occupancy\room-occupancy-0.test.csv@4.out         0.608732       0.314352
# Occupancy\room-occupancy-0.test.csv@5.out         0.621392       0.337527
# Occupancy\room-occupancy-1.test.csv@3.out         0.456739       0.121540
# Occupancy\room-occupancy-1.test.csv@4.out         0.278404       0.156264
# Occupancy\room-occupancy.train.csv@3.out          0.528567       0.111967
# Occupancy\room-occupancy.train.csv@4.out          0.490911       0.156121
# Occupancy\room-occupancy.train.csv@5.out          0.356702       0.173030
#
#                                            convnet_128_score  ...  \
# filename                                                      ...
# Occupancy\room-occupancy-0.test.csv@1.out           0.518969  ...
# Occupancy\room-occupancy-0.test.csv@2.out           0.623132  ...
# Occupancy\room-occupancy-0.test.csv@3.out           0.230645  ...
# Occupancy\room-occupancy-0.test.csv@4.out           0.648555  ...
# Occupancy\room-occupancy-0.test.csv@5.out           0.603909  ...
# Occupancy\room-occupancy-1.test.csv@3.out           0.802624  ...
# Occupancy\room-occupancy-1.test.csv@4.out           0.414188  ...
# Occupancy\room-occupancy.train.csv@3.out            0.111967  ...
# Occupancy\room-occupancy.train.csv@4.out            0.686333  ...
# Occupancy\room-occupancy.train.csv@5.out            0.727351  ...
#
#                                           knn_1024_inf  resnet_1024_score  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out     0.013617           0.518969
# Occupancy\room-occupancy-0.test.csv@2.out     0.018874           0.345203
# Occupancy\room-occupancy-0.test.csv@3.out     0.012443           0.230645
# Occupancy\room-occupancy-0.test.csv@4.out     0.018264           0.648555
# Occupancy\room-occupancy-0.test.csv@5.out     0.021372           0.337527
# Occupancy\room-occupancy-1.test.csv@3.out     0.025952           0.121540
# Occupancy\room-occupancy-1.test.csv@4.out     0.023317           0.156264
# Occupancy\room-occupancy.train.csv@3.out      0.020742           0.109323
# Occupancy\room-occupancy.train.csv@4.out      0.024475           0.686333
# Occupancy\room-occupancy.train.csv@5.out      0.021555           0.727351
#
#                                            resnet_1024_class resnet_1024_inf  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out               POLY        0.002709
# Occupancy\room-occupancy-0.test.csv@2.out                 MP        0.002646
# Occupancy\room-occupancy-0.test.csv@3.out                 MP        0.003095
# Occupancy\room-occupancy-0.test.csv@4.out               POLY        0.002960
# Occupancy\room-occupancy-0.test.csv@5.out                 MP        0.008135
# Occupancy\room-occupancy-1.test.csv@3.out                 MP        0.005240
# Occupancy\room-occupancy-1.test.csv@4.out                 MP        0.185245
# Occupancy\room-occupancy.train.csv@3.out                 LOF        0.005206
# Occupancy\room-occupancy.train.csv@4.out             IFOREST        0.009133
# Occupancy\room-occupancy.train.csv@5.out                POLY        0.005190
#
#                                            rocket_128_score  rocket_128_class  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out          0.384452               LOF
# Occupancy\room-occupancy-0.test.csv@2.out          0.514579               LOF
# Occupancy\room-occupancy-0.test.csv@3.out          0.230645                MP
# Occupancy\room-occupancy-0.test.csv@4.out          0.382609               LOF
# Occupancy\room-occupancy-0.test.csv@5.out          0.421117               LOF
# Occupancy\room-occupancy-1.test.csv@3.out          0.518629          IFOREST1
# Occupancy\room-occupancy-1.test.csv@4.out          0.182028               LOF
# Occupancy\room-occupancy.train.csv@3.out           0.427921          IFOREST1
# Occupancy\room-occupancy.train.csv@4.out           0.142756               LOF
# Occupancy\room-occupancy.train.csv@5.out           0.222892               LOF
#
#                                           rocket_128_inf  sit_stem_512_score  \
# filename
# Occupancy\room-occupancy-0.test.csv@1.out       0.069620            0.518969
# Occupancy\room-occupancy-0.test.csv@2.out       0.068677            0.623132
# Occupancy\room-occupancy-0.test.csv@3.out       0.076801            0.230645
# Occupancy\room-occupancy-0.test.csv@4.out       0.073115            0.648555
# Occupancy\room-occupancy-0.test.csv@5.out       0.069955            0.603909
# Occupancy\room-occupancy-1.test.csv@3.out       0.082586            0.121540
# Occupancy\room-occupancy-1.test.csv@4.out       0.088195            0.231276
# Occupancy\room-occupancy.train.csv@3.out        0.082536            0.111967
# Occupancy\room-occupancy.train.csv@4.out        0.077718            0.686333
# Occupancy\room-occupancy.train.csv@5.out        0.079505            0.727351
#
#                                            sit_stem_512_class sit_stem_512_inf
# filename
# Occupancy\room-occupancy-0.test.csv@1.out                POLY         0.010091
# Occupancy\room-occupancy-0.test.csv@2.out                POLY         0.010526
# Occupancy\room-occupancy-0.test.csv@3.out                  MP         0.010034
# Occupancy\room-occupancy-0.test.csv@4.out                POLY         0.011106
# Occupancy\room-occupancy-0.test.csv@5.out                POLY         0.014855
# Occupancy\room-occupancy-1.test.csv@3.out                  MP         0.009923
# Occupancy\room-occupancy-1.test.csv@4.out                 PCA         0.192515
# Occupancy\room-occupancy.train.csv@3.out                   MP         0.010633
# Occupancy\room-occupancy.train.csv@4.out              IFOREST         0.024067
# Occupancy\room-occupancy.train.csv@5.out                 POLY         0.010423
#
# [10 rows x 24 columns]
#                  label    Oracle   Avg Ens  best_ad_train  average_ad_train  \
# filename
# MGAB\1.test.out    LOF  0.353189  0.021960       0.003070          0.071560
# MGAB\10.test.out   LOF  0.768355  0.006882       0.002409          0.078286
# MGAB\2.test.out    LOF  0.628307  0.010579       0.002402          0.078844
# MGAB\3.test.out    LOF  0.310986  0.026054       0.002268          0.039945
# MGAB\4.test.out    LOF  0.605557  0.007536       0.005303          0.104501
# MGAB\5.test.out    LOF  0.587363  0.014222       0.002418          0.078841
# MGAB\6.test.out    LOF  0.641412  0.012867       0.002508          0.077604
# MGAB\7.test.out    LOF  0.549607  0.006791       0.002303          0.077427
# MGAB\8.test.out    LOF  0.532301  0.032211       0.002328          0.075512
# MGAB\9.test.out    LOF  0.510162  0.023283       0.007819          0.066693
#
#                   worst_ad_train  best_ad_test  average_ad_test  \
# filename
# MGAB\1.test.out         0.003322      0.347385         0.071560
# MGAB\10.test.out        0.001998      0.768355         0.078286
# MGAB\2.test.out         0.002021      0.628307         0.078844
# MGAB\3.test.out         0.003125      0.310986         0.039945
# MGAB\4.test.out         0.001693      0.549402         0.104501
# MGAB\5.test.out         0.002295      0.587363         0.078841
# MGAB\6.test.out         0.003087      0.641412         0.077604
# MGAB\7.test.out         0.002735      0.549607         0.077427
# MGAB\8.test.out         0.003625      0.532301         0.075512
# MGAB\9.test.out         0.004173      0.510162         0.066693
#
#                   worst_ad_test  convnet_128_score  ... knn_1024_inf  \
# filename                                            ...
# MGAB\1.test.out        0.002333           0.003070  ...     0.025630
# MGAB\10.test.out       0.002620           0.002409  ...     0.031539
# MGAB\2.test.out        0.002082           0.002402  ...     0.028218
# MGAB\3.test.out        0.003614           0.003125  ...     0.029586
# MGAB\4.test.out        0.001797           0.005303  ...     0.025354
# MGAB\5.test.out        0.001931           0.002418  ...     0.018763
# MGAB\6.test.out        0.002947           0.002508  ...     0.029496
# MGAB\7.test.out        0.002727           0.002735  ...     0.024343
# MGAB\8.test.out        0.002756           0.003625  ...     0.027819
# MGAB\9.test.out        0.003527           0.007819  ...     0.016369
#
#                   resnet_1024_score  resnet_1024_class resnet_1024_inf  \
# filename
# MGAB\1.test.out            0.003070              NORMA        0.027744
# MGAB\10.test.out           0.002409              NORMA        0.022977
# MGAB\2.test.out            0.002402              NORMA        0.026829
# MGAB\3.test.out            0.002268              NORMA        0.202318
# MGAB\4.test.out            0.005303              NORMA        0.027894
# MGAB\5.test.out            0.002418              NORMA        0.028944
# MGAB\6.test.out            0.002508              NORMA        0.024025
# MGAB\7.test.out            0.002303              NORMA        0.025351
# MGAB\8.test.out            0.002328              NORMA        0.022821
# MGAB\9.test.out            0.007819              NORMA        0.023162
#
#                   rocket_128_score  rocket_128_class rocket_128_inf  \
# filename
# MGAB\1.test.out           0.003070             NORMA       0.226298
# MGAB\10.test.out          0.002409             NORMA       0.244759
# MGAB\2.test.out           0.002402             NORMA       0.210842
# MGAB\3.test.out           0.002268             NORMA       0.238325
# MGAB\4.test.out           0.005303             NORMA       0.218905
# MGAB\5.test.out           0.002418             NORMA       0.222346
# MGAB\6.test.out           0.002508             NORMA       0.232856
# MGAB\7.test.out           0.002303             NORMA       0.214236
# MGAB\8.test.out           0.002328             NORMA       0.225979
# MGAB\9.test.out           0.007819             NORMA       0.222647
#
#                   sit_stem_512_score  sit_stem_512_class sit_stem_512_inf
# filename
# MGAB\1.test.out             0.003070               NORMA         0.057819
# MGAB\10.test.out            0.002409               NORMA         0.060978
# MGAB\2.test.out             0.002402               NORMA         0.055841
# MGAB\3.test.out             0.002268               NORMA         0.271751
# MGAB\4.test.out             0.005303               NORMA         0.056862
# MGAB\5.test.out             0.002418               NORMA         0.062341
# MGAB\6.test.out             0.002508               NORMA         0.057156
# MGAB\7.test.out             0.002303               NORMA         0.058100
# MGAB\8.test.out             0.002328               NORMA         0.055443
# MGAB\9.test.out             0.007819               NORMA         0.056938
#
# [10 rows x 24 columns]
#                                      label    Oracle   Avg Ens  best_ad_train  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out    PCA  0.798575  0.858724       0.390882
# OPPORTUNITY\S1-ADL1.test.csv@38.out    PCA  0.706428  0.866094       0.225279
# OPPORTUNITY\S1-ADL1.test.csv@42.out  NORMA  0.318566  0.041456       0.318566
# OPPORTUNITY\S1-ADL1.test.csv@66.out  NORMA  0.493548  0.039612       0.493548
# OPPORTUNITY\S1-ADL1.test.csv@76.out    PCA  0.866328  0.791772       0.032779
# ...                                    ...       ...       ...            ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out    LOF  0.515493  0.334672       0.052936
# OPPORTUNITY\S4-ADL5.test.csv@91.out   HBOS  0.881111  0.737733       0.249814
# OPPORTUNITY\S4-ADL5.test.csv@92.out  NORMA  0.417978  0.028370       0.417978
# OPPORTUNITY\S4-ADL5.test.csv@94.out  NORMA  0.404638  0.045416       0.404638
# OPPORTUNITY\S4-ADL5.test.csv@96.out     MP  0.228121  0.192135       0.134712
#
#                                      average_ad_train  worst_ad_train  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out          0.235310        0.016317
# OPPORTUNITY\S1-ADL1.test.csv@38.out          0.229818        0.015588
# OPPORTUNITY\S1-ADL1.test.csv@42.out          0.070089        0.014746
# OPPORTUNITY\S1-ADL1.test.csv@66.out          0.121399        0.016088
# OPPORTUNITY\S1-ADL1.test.csv@76.out          0.312388        0.019987
# ...                                               ...             ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out          0.162289        0.023080
# OPPORTUNITY\S4-ADL5.test.csv@91.out          0.284236        0.021987
# OPPORTUNITY\S4-ADL5.test.csv@92.out          0.087447        0.021960
# OPPORTUNITY\S4-ADL5.test.csv@94.out          0.110140        0.021721
# OPPORTUNITY\S4-ADL5.test.csv@96.out          0.099956        0.018774
#
#                                      best_ad_test  average_ad_test  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out      0.390882         0.235310
# OPPORTUNITY\S1-ADL1.test.csv@38.out      0.225279         0.229818
# OPPORTUNITY\S1-ADL1.test.csv@42.out      0.318566         0.070089
# OPPORTUNITY\S1-ADL1.test.csv@66.out      0.493548         0.121399
# OPPORTUNITY\S1-ADL1.test.csv@76.out      0.032779         0.312388
# ...                                           ...              ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out      0.052936         0.162289
# OPPORTUNITY\S4-ADL5.test.csv@91.out      0.249814         0.284236
# OPPORTUNITY\S4-ADL5.test.csv@92.out      0.417978         0.087447
# OPPORTUNITY\S4-ADL5.test.csv@94.out      0.404638         0.110140
# OPPORTUNITY\S4-ADL5.test.csv@96.out      0.134712         0.099956
#
#                                      worst_ad_test  convnet_128_score  ...  \
# filename                                                               ...
# OPPORTUNITY\S1-ADL1.test.csv@16.out       0.014222           0.014222  ...
# OPPORTUNITY\S1-ADL1.test.csv@38.out       0.013290           0.013290  ...
# OPPORTUNITY\S1-ADL1.test.csv@42.out       0.013742           0.034513  ...
# OPPORTUNITY\S1-ADL1.test.csv@66.out       0.012985           0.360346  ...
# OPPORTUNITY\S1-ADL1.test.csv@76.out       0.013649           0.511402  ...
# ...                                            ...                ...  ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out       0.024708           0.515493  ...
# OPPORTUNITY\S4-ADL5.test.csv@91.out       0.031576           0.015493  ...
# OPPORTUNITY\S4-ADL5.test.csv@92.out       0.016639           0.015493  ...
# OPPORTUNITY\S4-ADL5.test.csv@94.out       0.017925           0.352092  ...
# OPPORTUNITY\S4-ADL5.test.csv@96.out       0.022158           0.015493  ...
#
#                                     knn_1024_inf  resnet_1024_score  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out     0.021018           0.506630
# OPPORTUNITY\S1-ADL1.test.csv@38.out     0.023531           0.651393
# OPPORTUNITY\S1-ADL1.test.csv@42.out     0.027720           0.013271
# OPPORTUNITY\S1-ADL1.test.csv@66.out     0.021520           0.360346
# OPPORTUNITY\S1-ADL1.test.csv@76.out     0.028912           0.013649
# ...                                          ...                ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out     0.027867           0.024708
# OPPORTUNITY\S4-ADL5.test.csv@91.out     0.026655           0.249814
# OPPORTUNITY\S4-ADL5.test.csv@92.out     0.026861           0.261826
# OPPORTUNITY\S4-ADL5.test.csv@94.out     0.022911           0.352092
# OPPORTUNITY\S4-ADL5.test.csv@96.out     0.015718           0.018774
#
#                                      resnet_1024_class resnet_1024_inf  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out            IFOREST        0.018315
# OPPORTUNITY\S1-ADL1.test.csv@38.out                PCA        0.013328
# OPPORTUNITY\S1-ADL1.test.csv@42.out                PCA        0.021110
# OPPORTUNITY\S1-ADL1.test.csv@66.out                LOF        0.022435
# OPPORTUNITY\S1-ADL1.test.csv@76.out               POLY        0.013352
# ...                                                ...             ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out               POLY        0.012559
# OPPORTUNITY\S4-ADL5.test.csv@91.out              NORMA        0.013968
# OPPORTUNITY\S4-ADL5.test.csv@92.out                 MP        0.010965
# OPPORTUNITY\S4-ADL5.test.csv@94.out                 MP        0.014422
# OPPORTUNITY\S4-ADL5.test.csv@96.out              OCSVM        0.013782
#
#                                      rocket_128_score  rocket_128_class  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out          0.506630           IFOREST
# OPPORTUNITY\S1-ADL1.test.csv@38.out          0.706428           IFOREST
# OPPORTUNITY\S1-ADL1.test.csv@42.out          0.013960          IFOREST1
# OPPORTUNITY\S1-ADL1.test.csv@66.out          0.012721           IFOREST
# OPPORTUNITY\S1-ADL1.test.csv@76.out          0.811386           IFOREST
# ...                                               ...               ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out          0.161942          IFOREST1
# OPPORTUNITY\S4-ADL5.test.csv@91.out          0.333919          IFOREST1
# OPPORTUNITY\S4-ADL5.test.csv@92.out          0.016414           IFOREST
# OPPORTUNITY\S4-ADL5.test.csv@94.out          0.018965           IFOREST
# OPPORTUNITY\S4-ADL5.test.csv@96.out          0.079556              LSTM
#
#                                     rocket_128_inf  sit_stem_512_score  \
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out       0.138818            0.014222
# OPPORTUNITY\S1-ADL1.test.csv@38.out       0.152517            0.013290
# OPPORTUNITY\S1-ADL1.test.csv@42.out       0.144667            0.318566
# OPPORTUNITY\S1-ADL1.test.csv@66.out       0.154590            0.012985
# OPPORTUNITY\S1-ADL1.test.csv@76.out       0.138856            0.013649
# ...                                            ...                 ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out       0.112074            0.024708
# OPPORTUNITY\S4-ADL5.test.csv@91.out       0.118721            0.249814
# OPPORTUNITY\S4-ADL5.test.csv@92.out       0.112825            0.261826
# OPPORTUNITY\S4-ADL5.test.csv@94.out       0.110789            0.404638
# OPPORTUNITY\S4-ADL5.test.csv@96.out       0.111072            0.134712
#
#                                      sit_stem_512_class sit_stem_512_inf
# filename
# OPPORTUNITY\S1-ADL1.test.csv@16.out                POLY         0.034760
# OPPORTUNITY\S1-ADL1.test.csv@38.out                POLY         0.029661
# OPPORTUNITY\S1-ADL1.test.csv@42.out               NORMA         0.029512
# OPPORTUNITY\S1-ADL1.test.csv@66.out                POLY         0.032294
# OPPORTUNITY\S1-ADL1.test.csv@76.out                POLY         0.029716
# ...                                                 ...              ...
# OPPORTUNITY\S4-ADL5.test.csv@89.out                POLY         0.021317
# OPPORTUNITY\S4-ADL5.test.csv@91.out               NORMA         0.018244
# OPPORTUNITY\S4-ADL5.test.csv@92.out                  MP         0.017691
# OPPORTUNITY\S4-ADL5.test.csv@94.out               NORMA         0.019619
# OPPORTUNITY\S4-ADL5.test.csv@96.out               NORMA         0.017768
#
# [465 rows x 24 columns]
#                                 label    Oracle   Avg Ens  best_ad_train  \
# filename
# SensorScope\stb-10.test.out      HBOS  0.276425  0.257607       0.229053
# SensorScope\stb-11.test.out       LOF  0.573259  0.237110       0.259366
# SensorScope\stb-12.test.out     NORMA  0.353799  0.306421       0.353799
# SensorScope\stb-13.test.out     NORMA  0.326588  0.287962       0.326588
# SensorScope\stb-14.test.out      HBOS  0.289879  0.255148       0.240389
# SensorScope\stb-15.test.out   IFOREST  0.354205  0.353899       0.301886
# SensorScope\stb-17.test.out      POLY  0.404935  0.235212       0.202111
# SensorScope\stb-18.test.out   IFOREST  0.316916  0.213923       0.179267
# SensorScope\stb-19.test.out      HBOS  0.479144  0.502441       0.371947
# SensorScope\stb-2.test.out   IFOREST1  0.338748  0.147384       0.086707
# SensorScope\stb-20.test.out        AE  0.299645  0.255131       0.299645
# SensorScope\stb-25.test.out       LOF  0.472707  0.255259       0.344925
# SensorScope\stb-28.test.out       LOF  0.591398  0.272371       0.274420
# SensorScope\stb-29.test.out      POLY  0.369367  0.303257       0.146547
# SensorScope\stb-3.test.out        CNN  0.434213  0.364298       0.339322
# SensorScope\stb-31.test.out       LOF  0.293778  0.247626       0.293778
# SensorScope\stb-32.test.out       LOF  0.562108  0.294060       0.370729
# SensorScope\stb-4.test.out         AE  0.323303  0.310531       0.286837
# SensorScope\stb-5.test.out   IFOREST1  0.301300  0.287429       0.196092
# SensorScope\stb-6.test.out        PCA  0.320456  0.287213       0.239140
# SensorScope\stb-7.test.out       POLY  0.533824  0.386261       0.288748
# SensorScope\stb-8.test.out      NORMA  0.310211  0.317466       0.303688
# SensorScope\stb-9.test.out       POLY  0.563714  0.395767       0.238890
#
#                              average_ad_train  worst_ad_train  best_ad_test  \
# filename
# SensorScope\stb-10.test.out          0.240579        0.266011      0.237024
# SensorScope\stb-11.test.out          0.254504        0.223132      0.287337
# SensorScope\stb-12.test.out          0.268003        0.232785      0.237639
# SensorScope\stb-13.test.out          0.266502        0.259727      0.268485
# SensorScope\stb-14.test.out          0.244960        0.256080      0.220237
# SensorScope\stb-15.test.out          0.306199        0.337765      0.325739
# SensorScope\stb-17.test.out          0.233980        0.199942      0.404935
# SensorScope\stb-18.test.out          0.244088        0.186087      0.299249
# SensorScope\stb-19.test.out          0.377945        0.324404      0.344010
# SensorScope\stb-2.test.out           0.166686        0.078729      0.227733
# SensorScope\stb-20.test.out          0.241129        0.248043      0.255788
# SensorScope\stb-25.test.out          0.251453        0.259411      0.260290
# SensorScope\stb-28.test.out          0.267442        0.268580      0.272263
# SensorScope\stb-29.test.out          0.205428        0.173076      0.369367
# SensorScope\stb-3.test.out           0.293988        0.350247      0.293241
# SensorScope\stb-31.test.out          0.207503        0.251003      0.227858
# SensorScope\stb-32.test.out          0.270191        0.260860      0.269312
# SensorScope\stb-4.test.out           0.261973        0.300146      0.272397
# SensorScope\stb-5.test.out           0.239769        0.252418      0.278719
# SensorScope\stb-6.test.out           0.252587        0.255950      0.311797
# SensorScope\stb-7.test.out           0.312618        0.301186      0.533824
# SensorScope\stb-8.test.out           0.284035        0.310211      0.303421
# SensorScope\stb-9.test.out           0.309042        0.338223      0.563714
#
#                              average_ad_test  worst_ad_test  \
# filename
# SensorScope\stb-10.test.out         0.240579       0.209821
# SensorScope\stb-11.test.out         0.254504       0.107101
# SensorScope\stb-12.test.out         0.268003       0.276649
# SensorScope\stb-13.test.out         0.266502       0.258297
# SensorScope\stb-14.test.out         0.244960       0.204448
# SensorScope\stb-15.test.out         0.306199       0.278497
# SensorScope\stb-17.test.out         0.233980       0.120014
# SensorScope\stb-18.test.out         0.244088       0.116290
# SensorScope\stb-19.test.out         0.377945       0.135866
# SensorScope\stb-2.test.out          0.166686       0.064276
# SensorScope\stb-20.test.out         0.241129       0.226658
# SensorScope\stb-25.test.out         0.251453       0.108842
# SensorScope\stb-28.test.out         0.267442       0.108460
# SensorScope\stb-29.test.out         0.205428       0.074356
# SensorScope\stb-3.test.out          0.293988       0.266424
# SensorScope\stb-31.test.out         0.207503       0.102982
# SensorScope\stb-32.test.out         0.270191       0.107235
# SensorScope\stb-4.test.out          0.261973       0.256181
# SensorScope\stb-5.test.out          0.239769       0.194575
# SensorScope\stb-6.test.out          0.252587       0.117958
# SensorScope\stb-7.test.out          0.312618       0.145162
# SensorScope\stb-8.test.out          0.284035       0.269147
# SensorScope\stb-9.test.out          0.309042       0.129994
#
#                              convnet_128_score  ... knn_1024_inf  \
# filename                                        ...
# SensorScope\stb-10.test.out           0.237024  ...     0.024503
# SensorScope\stb-11.test.out           0.287337  ...     0.024557
# SensorScope\stb-12.test.out           0.237639  ...     0.028232
# SensorScope\stb-13.test.out           0.268485  ...     0.020455
# SensorScope\stb-14.test.out           0.220237  ...     0.022525
# SensorScope\stb-15.test.out           0.325739  ...     0.022482
# SensorScope\stb-17.test.out           0.404935  ...     0.020666
# SensorScope\stb-18.test.out           0.299249  ...     0.024311
# SensorScope\stb-19.test.out           0.344010  ...     0.014546
# SensorScope\stb-2.test.out            0.338748  ...     0.032372
# SensorScope\stb-20.test.out           0.255788  ...     0.022512
# SensorScope\stb-25.test.out           0.260290  ...     0.016777
# SensorScope\stb-28.test.out           0.272263  ...     0.022717
# SensorScope\stb-29.test.out           0.369367  ...     0.017317
# SensorScope\stb-3.test.out            0.293241  ...     0.023693
# SensorScope\stb-31.test.out           0.227858  ...     0.020004
# SensorScope\stb-32.test.out           0.269312  ...     0.024548
# SensorScope\stb-4.test.out            0.272397  ...     0.017285
# SensorScope\stb-5.test.out            0.278719  ...     0.024682
# SensorScope\stb-6.test.out            0.311797  ...     0.015688
# SensorScope\stb-7.test.out            0.533824  ...     0.025521
# SensorScope\stb-8.test.out            0.303421  ...     0.025223
# SensorScope\stb-9.test.out            0.563714  ...     0.024253
#
#                              resnet_1024_score  resnet_1024_class  \
# filename
# SensorScope\stb-10.test.out           0.270754            IFOREST
# SensorScope\stb-11.test.out           0.205343            IFOREST
# SensorScope\stb-12.test.out           0.294545            IFOREST
# SensorScope\stb-13.test.out           0.267647            IFOREST
# SensorScope\stb-14.test.out           0.257764            IFOREST
# SensorScope\stb-15.test.out           0.354205            IFOREST
# SensorScope\stb-17.test.out           0.312435            IFOREST
# SensorScope\stb-18.test.out           0.316916            IFOREST
# SensorScope\stb-19.test.out           0.479144            IFOREST
# SensorScope\stb-2.test.out            0.284566            IFOREST
# SensorScope\stb-20.test.out           0.251197            IFOREST
# SensorScope\stb-25.test.out           0.214893            IFOREST
# SensorScope\stb-28.test.out           0.241831            IFOREST
# SensorScope\stb-29.test.out           0.369367               POLY
# SensorScope\stb-3.test.out            0.285340            IFOREST
# SensorScope\stb-31.test.out           0.206781            IFOREST
# SensorScope\stb-32.test.out           0.232978            IFOREST
# SensorScope\stb-4.test.out            0.219342            IFOREST
# SensorScope\stb-5.test.out            0.301300            IFOREST
# SensorScope\stb-6.test.out            0.301257            IFOREST
# SensorScope\stb-7.test.out            0.339345            IFOREST
# SensorScope\stb-8.test.out            0.271780            IFOREST
# SensorScope\stb-9.test.out            0.365284            IFOREST
#
#                             resnet_1024_inf  rocket_128_score  \
# filename
# SensorScope\stb-10.test.out        0.010458          0.229053
# SensorScope\stb-11.test.out        0.008432          0.259366
# SensorScope\stb-12.test.out        0.008286          0.353799
# SensorScope\stb-13.test.out        0.010223          0.326588
# SensorScope\stb-14.test.out        0.008427          0.240389
# SensorScope\stb-15.test.out        0.174193          0.301886
# SensorScope\stb-17.test.out        0.010016          0.202111
# SensorScope\stb-18.test.out        0.007734          0.179267
# SensorScope\stb-19.test.out        0.008363          0.371947
# SensorScope\stb-2.test.out         0.008743          0.338748
# SensorScope\stb-20.test.out        0.008429          0.299645
# SensorScope\stb-25.test.out        0.006989          0.344925
# SensorScope\stb-28.test.out        0.009585          0.274420
# SensorScope\stb-29.test.out        0.007524          0.146547
# SensorScope\stb-3.test.out         0.008599          0.339322
# SensorScope\stb-31.test.out        0.006953          0.293778
# SensorScope\stb-32.test.out        0.007201          0.370729
# SensorScope\stb-4.test.out         0.008358          0.286837
# SensorScope\stb-5.test.out         0.008307          0.196092
# SensorScope\stb-6.test.out         0.009957          0.239140
# SensorScope\stb-7.test.out         0.007543          0.288748
# SensorScope\stb-8.test.out         0.008416          0.303688
# SensorScope\stb-9.test.out         0.008245          0.238890
#
#                              rocket_128_class rocket_128_inf  \
# filename
# SensorScope\stb-10.test.out             NORMA       0.112088
# SensorScope\stb-11.test.out             NORMA       0.110220
# SensorScope\stb-12.test.out             NORMA       0.111843
# SensorScope\stb-13.test.out             NORMA       0.110821
# SensorScope\stb-14.test.out             NORMA       0.112054
# SensorScope\stb-15.test.out             NORMA       0.116087
# SensorScope\stb-17.test.out             NORMA       0.105463
# SensorScope\stb-18.test.out             NORMA       0.106902
# SensorScope\stb-19.test.out             NORMA       0.114526
# SensorScope\stb-2.test.out           IFOREST1       0.112869
# SensorScope\stb-20.test.out             NORMA       0.110591
# SensorScope\stb-25.test.out             NORMA       0.096396
# SensorScope\stb-28.test.out             NORMA       0.100837
# SensorScope\stb-29.test.out             NORMA       0.103476
# SensorScope\stb-3.test.out              NORMA       0.120323
# SensorScope\stb-31.test.out             NORMA       0.099237
# SensorScope\stb-32.test.out             NORMA       0.098221
# SensorScope\stb-4.test.out              NORMA       0.110932
# SensorScope\stb-5.test.out              NORMA       0.107436
# SensorScope\stb-6.test.out              NORMA       0.105741
# SensorScope\stb-7.test.out              NORMA       0.114713
# SensorScope\stb-8.test.out              NORMA       0.118269
# SensorScope\stb-9.test.out              NORMA       0.117600
#
#                              sit_stem_512_score  sit_stem_512_class  \
# filename
# SensorScope\stb-10.test.out            0.276425                HBOS
# SensorScope\stb-11.test.out            0.287337                POLY
# SensorScope\stb-12.test.out            0.264033                HBOS
# SensorScope\stb-13.test.out            0.263284                HBOS
# SensorScope\stb-14.test.out            0.220237                POLY
# SensorScope\stb-15.test.out            0.325739                POLY
# SensorScope\stb-17.test.out            0.243635                HBOS
# SensorScope\stb-18.test.out            0.299249                POLY
# SensorScope\stb-19.test.out            0.344010                POLY
# SensorScope\stb-2.test.out             0.338748            IFOREST1
# SensorScope\stb-20.test.out            0.255788                POLY
# SensorScope\stb-25.test.out            0.260290                POLY
# SensorScope\stb-28.test.out            0.272263                POLY
# SensorScope\stb-29.test.out            0.369367                POLY
# SensorScope\stb-3.test.out             0.293241                POLY
# SensorScope\stb-31.test.out            0.227858                POLY
# SensorScope\stb-32.test.out            0.232978             IFOREST
# SensorScope\stb-4.test.out             0.272397                POLY
# SensorScope\stb-5.test.out             0.278719                POLY
# SensorScope\stb-6.test.out             0.301257             IFOREST
# SensorScope\stb-7.test.out             0.533824                POLY
# SensorScope\stb-8.test.out             0.303421                POLY
# SensorScope\stb-9.test.out             0.322948            IFOREST1
#
#                             sit_stem_512_inf
# filename
# SensorScope\stb-10.test.out         0.021881
# SensorScope\stb-11.test.out         0.017471
# SensorScope\stb-12.test.out         0.019101
# SensorScope\stb-13.test.out         0.017542
# SensorScope\stb-14.test.out         0.017701
# SensorScope\stb-15.test.out         0.201071
# SensorScope\stb-17.test.out         0.019473
# SensorScope\stb-18.test.out         0.015436
# SensorScope\stb-19.test.out         0.017936
# SensorScope\stb-2.test.out          0.017585
# SensorScope\stb-20.test.out         0.017642
# SensorScope\stb-25.test.out         0.015296
# SensorScope\stb-28.test.out         0.018592
# SensorScope\stb-29.test.out         0.013939
# SensorScope\stb-3.test.out          0.017847
# SensorScope\stb-31.test.out         0.014103
# SensorScope\stb-32.test.out         0.013872
# SensorScope\stb-4.test.out          0.017742
# SensorScope\stb-5.test.out          0.017675
# SensorScope\stb-6.test.out          0.019099
# SensorScope\stb-7.test.out          0.020791
# SensorScope\stb-8.test.out          0.017440
# SensorScope\stb-9.test.out          0.019922
#
# [23 rows x 24 columns]
# ...
# ECG\MBA_ECG14046_data_4.out                 MP       0.388402
# ECG\MBA_ECG14046_data_40.out                MP       0.403023
# ECG\MBA_ECG14046_data_41.out                MP       0.399878
# ECG\MBA_ECG14046_data_42.out                MP       0.426117
# ECG\MBA_ECG14046_data_43.out                MP       0.395710
# ECG\MBA_ECG14046_data_44.out                MP       0.401927
# ECG\MBA_ECG14046_data_45.out                MP       0.411782
# ECG\MBA_ECG14046_data_46.out                MP       0.411118
# ECG\MBA_ECG14046_data_5.out                 MP       0.393139
# ECG\MBA_ECG14046_data_6.out                 MP       0.385709
# ECG\MBA_ECG14046_data_7.out                 MP       0.384741
# ECG\MBA_ECG14046_data_8.out                 MP       0.401024
# ECG\MBA_ECG14046_data_9.out                 MP       0.387128
# ECG\MBA_ECG801_data.out                     MP       0.391193
# ECG\MBA_ECG803_data.out                  NORMA       0.426272
# ECG\MBA_ECG805_data.out                     MP       0.397157
# ECG\MBA_ECG806_data.out                  NORMA       0.373415
# ECG\MBA_ECG820_data.out                  NORMA       0.381373
#
#                               sit_stem_512_score  sit_stem_512_class  \
# filename
# ECG\MBA_ECG14046_data_0.out             0.164315                  MP
# ECG\MBA_ECG14046_data_1.out             0.467945               NORMA
# ECG\MBA_ECG14046_data_10.out            0.171516                  MP
# ECG\MBA_ECG14046_data_11.out            0.152943                  MP
# ECG\MBA_ECG14046_data_12.out            0.542447               NORMA
# ECG\MBA_ECG14046_data_13.out            0.769789               NORMA
# ECG\MBA_ECG14046_data_14.out            0.802023               NORMA
# ECG\MBA_ECG14046_data_15.out            0.618129               NORMA
# ECG\MBA_ECG14046_data_16.out            0.820022               NORMA
# ECG\MBA_ECG14046_data_17.out            0.697752               NORMA
# ECG\MBA_ECG14046_data_18.out            0.423737                 PCA
# ECG\MBA_ECG14046_data_19.out            0.569803                 PCA
# ECG\MBA_ECG14046_data_2.out             0.115353                  MP
# ECG\MBA_ECG14046_data_20.out            0.591062                 PCA
# ECG\MBA_ECG14046_data_21.out            0.531502                 PCA
# ECG\MBA_ECG14046_data_22.out            0.474017               NORMA
# ECG\MBA_ECG14046_data_23.out            0.109517                  MP
# ECG\MBA_ECG14046_data_24.out            0.072297                  MP
# ECG\MBA_ECG14046_data_25.out            0.129128                  MP
# ECG\MBA_ECG14046_data_26.out            0.048429                  MP
# ECG\MBA_ECG14046_data_27.out            0.209578                  MP
# ECG\MBA_ECG14046_data_28.out            0.232570                  MP
# ECG\MBA_ECG14046_data_29.out            0.022847                  MP
# ECG\MBA_ECG14046_data_3.out             0.695891                 PCA
# ECG\MBA_ECG14046_data_30.out            0.049387                  MP
# ECG\MBA_ECG14046_data_31.out            0.097499                  MP
# ECG\MBA_ECG14046_data_32.out            0.169832                  MP
# ECG\MBA_ECG14046_data_33.out            0.144043                  MP
# ECG\MBA_ECG14046_data_34.out            0.073156                  MP
# ECG\MBA_ECG14046_data_35.out            0.107285                  MP
# ECG\MBA_ECG14046_data_36.out            0.507138               NORMA
# ECG\MBA_ECG14046_data_37.out            0.521529                 PCA
# ECG\MBA_ECG14046_data_38.out            0.539800                 PCA
# ECG\MBA_ECG14046_data_39.out            0.555437               NORMA
# ECG\MBA_ECG14046_data_4.out             0.619497                 PCA
# ECG\MBA_ECG14046_data_40.out            0.498323                 PCA
# ECG\MBA_ECG14046_data_41.out            0.560972                 PCA
# ECG\MBA_ECG14046_data_42.out            0.165733               NORMA
# ECG\MBA_ECG14046_data_43.out            0.566664                 PCA
# ECG\MBA_ECG14046_data_44.out            0.077532                  MP
# ECG\MBA_ECG14046_data_45.out            0.080519                  MP
# ECG\MBA_ECG14046_data_46.out            0.065562                  MP
# ECG\MBA_ECG14046_data_5.out             0.149017                  MP
# ECG\MBA_ECG14046_data_6.out             0.110469                  MP
# ECG\MBA_ECG14046_data_7.out             0.044257                  MP
# ECG\MBA_ECG14046_data_8.out             0.442231                 PCA
# ECG\MBA_ECG14046_data_9.out             0.519145                 PCA
# ECG\MBA_ECG801_data.out                 0.348630                 PCA
# ECG\MBA_ECG803_data.out                 0.920572               NORMA
# ECG\MBA_ECG805_data.out                 0.801171               NORMA
# ECG\MBA_ECG806_data.out                 0.648858               NORMA
# ECG\MBA_ECG820_data.out                 0.620320               NORMA
#
#                              sit_stem_512_inf
# filename
# ECG\MBA_ECG14046_data_0.out          0.126922
# ECG\MBA_ECG14046_data_1.out          0.140601
# ECG\MBA_ECG14046_data_10.out         0.129265
# ECG\MBA_ECG14046_data_11.out         0.139758
# ECG\MBA_ECG14046_data_12.out         0.126180
# ECG\MBA_ECG14046_data_13.out         0.127917
# ECG\MBA_ECG14046_data_14.out         0.342847
# ECG\MBA_ECG14046_data_15.out         0.129812
# ECG\MBA_ECG14046_data_16.out         0.130505
# ECG\MBA_ECG14046_data_17.out         0.130269
# ECG\MBA_ECG14046_data_18.out         0.128244
# ECG\MBA_ECG14046_data_19.out         0.127623
# ECG\MBA_ECG14046_data_2.out          0.131637
# ECG\MBA_ECG14046_data_20.out         0.128382
# ECG\MBA_ECG14046_data_21.out         0.144377
# ECG\MBA_ECG14046_data_22.out         0.128382
# ECG\MBA_ECG14046_data_23.out         0.127975
# ECG\MBA_ECG14046_data_24.out         0.131561
# ECG\MBA_ECG14046_data_25.out         0.127733
# ECG\MBA_ECG14046_data_26.out         0.127741
# ECG\MBA_ECG14046_data_27.out         0.137601
# ECG\MBA_ECG14046_data_28.out         0.128639
# ECG\MBA_ECG14046_data_29.out         0.127158
# ECG\MBA_ECG14046_data_3.out          0.129453
# ECG\MBA_ECG14046_data_30.out         0.129936
# ECG\MBA_ECG14046_data_31.out         0.134239
# ECG\MBA_ECG14046_data_32.out         0.127885
# ECG\MBA_ECG14046_data_33.out         0.127058
# ECG\MBA_ECG14046_data_34.out         0.131060
# ECG\MBA_ECG14046_data_35.out         0.128418
# ECG\MBA_ECG14046_data_36.out         0.129490
# ECG\MBA_ECG14046_data_37.out         0.130358
# ECG\MBA_ECG14046_data_38.out         0.126292
# ECG\MBA_ECG14046_data_39.out         0.129974
# ECG\MBA_ECG14046_data_4.out          0.129867
# ECG\MBA_ECG14046_data_40.out         0.125966
# ECG\MBA_ECG14046_data_41.out         0.129311
# ECG\MBA_ECG14046_data_42.out         0.130098
# ECG\MBA_ECG14046_data_43.out         0.128202
# ECG\MBA_ECG14046_data_44.out         0.128649
# ECG\MBA_ECG14046_data_45.out         0.127531
# ECG\MBA_ECG14046_data_46.out         0.142563
# ECG\MBA_ECG14046_data_5.out          0.144978
# ECG\MBA_ECG14046_data_6.out          0.127642
# ECG\MBA_ECG14046_data_7.out          0.144071
# ECG\MBA_ECG14046_data_8.out          0.128146
# ECG\MBA_ECG14046_data_9.out          0.126380
# ECG\MBA_ECG801_data.out              0.130301
# ECG\MBA_ECG803_data.out              0.128542
# ECG\MBA_ECG805_data.out              0.126933
# ECG\MBA_ECG806_data.out              0.128137
# ECG\MBA_ECG820_data.out              0.145006
#
# [52 rows x 24 columns]
#                                    label    Oracle   Avg Ens  best_ad_train  \
# filename
# SMD\machine-1-1.test.csv@1.out       PCA  0.677238  0.560722       0.171307
# SMD\machine-1-1.test.csv@10.out     POLY  0.638471  0.366630       0.074019
# SMD\machine-1-1.test.csv@12.out      PCA  0.655490  0.658331       0.088023
# SMD\machine-1-1.test.csv@14.out      LOF  0.459396  0.507020       0.359958
# SMD\machine-1-1.test.csv@19.out  IFOREST  0.320152  0.216815       0.067529
# ...                                  ...       ...       ...            ...
# SMD\machine-3-9.test.csv@21.out     POLY  0.406945  0.257177       0.024533
# SMD\machine-3-9.test.csv@25.out  IFOREST  0.178297  0.104895       0.007783
# SMD\machine-3-9.test.csv@31.out     POLY  0.422639  0.338621       0.028422
# SMD\machine-3-9.test.csv@35.out     HBOS  0.492778  0.612142       0.026840
# SMD\machine-3-9.test.csv@36.out     HBOS  0.492778  0.592606       0.011887
#
#                                  average_ad_train  worst_ad_train  \
# filename
# SMD\machine-1-1.test.csv@1.out           0.310391        0.424309
# SMD\machine-1-1.test.csv@10.out          0.298960        0.100587
# SMD\machine-1-1.test.csv@12.out          0.303329        0.205929
# SMD\machine-1-1.test.csv@14.out          0.290988        0.262969
# SMD\machine-1-1.test.csv@19.out          0.167987        0.134222
# ...                                           ...             ...
# SMD\machine-3-9.test.csv@21.out          0.086669        0.013730
# SMD\machine-3-9.test.csv@25.out          0.075001        0.011820
# SMD\machine-3-9.test.csv@31.out          0.093454        0.027982
# SMD\machine-3-9.test.csv@35.out          0.214916        0.188315
# SMD\machine-3-9.test.csv@36.out          0.211838        0.171696
#
#                                  best_ad_test  average_ad_test  worst_ad_test  \
# filename
# SMD\machine-1-1.test.csv@1.out       0.364615         0.310391       0.067279
# SMD\machine-1-1.test.csv@10.out      0.604505         0.298960       0.081972
# SMD\machine-1-1.test.csv@12.out      0.655490         0.303329       0.089808
# SMD\machine-1-1.test.csv@14.out      0.446525         0.290988       0.141164
# SMD\machine-1-1.test.csv@19.out      0.202153         0.167987       0.067867
# ...                                       ...              ...            ...
# SMD\machine-3-9.test.csv@21.out      0.406945         0.086669       0.025228
# SMD\machine-3-9.test.csv@25.out      0.153033         0.075001       0.006446
# SMD\machine-3-9.test.csv@31.out      0.422639         0.093454       0.026525
# SMD\machine-3-9.test.csv@35.out      0.342538         0.214916       0.033235
# SMD\machine-3-9.test.csv@36.out      0.342538         0.211838       0.036286
#
#                                  convnet_128_score  ... knn_1024_inf  \
# filename                                            ...
# SMD\machine-1-1.test.csv@1.out            0.364615  ...     0.014842
# SMD\machine-1-1.test.csv@10.out           0.494070  ...     0.025252
# SMD\machine-1-1.test.csv@12.out           0.505031  ...     0.019969
# SMD\machine-1-1.test.csv@14.out           0.409039  ...     0.024843
# SMD\machine-1-1.test.csv@19.out           0.202153  ...     0.025655
# ...                                            ...  ...          ...
# SMD\machine-3-9.test.csv@21.out           0.042409  ...     0.025891
# SMD\machine-3-9.test.csv@25.out           0.153033  ...     0.024532
# SMD\machine-3-9.test.csv@31.out           0.069885  ...     0.019178
# SMD\machine-3-9.test.csv@35.out           0.218430  ...     0.026036
# SMD\machine-3-9.test.csv@36.out           0.223107  ...     0.019167
#
#                                  resnet_1024_score  resnet_1024_class  \
# filename
# SMD\machine-1-1.test.csv@1.out            0.574545            IFOREST
# SMD\machine-1-1.test.csv@10.out           0.638471               HBOS
# SMD\machine-1-1.test.csv@12.out           0.238244           IFOREST1
# SMD\machine-1-1.test.csv@14.out           0.409039            IFOREST
# SMD\machine-1-1.test.csv@19.out           0.202153               POLY
# ...                                            ...                ...
# SMD\machine-3-9.test.csv@21.out           0.077449            IFOREST
# SMD\machine-3-9.test.csv@25.out           0.178297            IFOREST
# SMD\machine-3-9.test.csv@31.out           0.096567            IFOREST
# SMD\machine-3-9.test.csv@35.out           0.218430           IFOREST1
# SMD\machine-3-9.test.csv@36.out           0.223107           IFOREST1
#
#                                 resnet_1024_inf  rocket_128_score  \
# filename
# SMD\machine-1-1.test.csv@1.out         0.008298          0.081640
# SMD\machine-1-1.test.csv@10.out        0.015298          0.074019
# SMD\machine-1-1.test.csv@12.out        0.015801          0.097114
# SMD\machine-1-1.test.csv@14.out        0.010080          0.409039
# SMD\machine-1-1.test.csv@19.out        0.010558          0.089985
# ...                                         ...               ...
# SMD\machine-3-9.test.csv@21.out        0.009403          0.065675
# SMD\machine-3-9.test.csv@25.out        0.012581          0.008609
# SMD\machine-3-9.test.csv@31.out        0.013070          0.044932
# SMD\machine-3-9.test.csv@35.out        0.014142          0.033235
# SMD\machine-3-9.test.csv@36.out        0.012041          0.036286
#
#                                  rocket_128_class rocket_128_inf  \
# filename
# SMD\machine-1-1.test.csv@1.out                LOF       0.112694
# SMD\machine-1-1.test.csv@10.out             NORMA       0.108590
# SMD\machine-1-1.test.csv@12.out               CNN       0.108977
# SMD\machine-1-1.test.csv@14.out           IFOREST       0.118504
# SMD\machine-1-1.test.csv@19.out               LOF       0.119125
# ...                                           ...            ...
# SMD\machine-3-9.test.csv@21.out               LOF       0.120313
# SMD\machine-3-9.test.csv@25.out               CNN       0.111363
# SMD\machine-3-9.test.csv@31.out               LOF       0.107834
# SMD\machine-3-9.test.csv@35.out                MP       0.107184
# SMD\machine-3-9.test.csv@36.out                MP       0.108247
#
#                                  sit_stem_512_score  sit_stem_512_class  \
# filename
# SMD\machine-1-1.test.csv@1.out             0.081640                 LOF
# SMD\machine-1-1.test.csv@10.out            0.089681                 CNN
# SMD\machine-1-1.test.csv@12.out            0.655490                POLY
# SMD\machine-1-1.test.csv@14.out            0.446525                POLY
# SMD\machine-1-1.test.csv@19.out            0.202153                POLY
# ...                                             ...                 ...
# SMD\machine-3-9.test.csv@21.out            0.065675                 LOF
# SMD\machine-3-9.test.csv@25.out            0.153033                POLY
# SMD\machine-3-9.test.csv@31.out            0.044932                 LOF
# SMD\machine-3-9.test.csv@35.out            0.218430            IFOREST1
# SMD\machine-3-9.test.csv@36.out            0.223107            IFOREST1
#
#                                 sit_stem_512_inf
# filename
# SMD\machine-1-1.test.csv@1.out          0.017891
# SMD\machine-1-1.test.csv@10.out         0.017605
# SMD\machine-1-1.test.csv@12.out         0.017906
# SMD\machine-1-1.test.csv@14.out         0.017504
# SMD\machine-1-1.test.csv@19.out         0.020585
# ...                                          ...
# SMD\machine-3-9.test.csv@21.out         0.017542
# SMD\machine-3-9.test.csv@25.out         0.017402
# SMD\machine-3-9.test.csv@31.out         0.017979
# SMD\machine-3-9.test.csv@35.out         0.017398
# SMD\machine-3-9.test.csv@36.out         0.018975
#
# [278 rows x 24 columns]

# %% [markdown]
# ## Trained on 15 datasets, tested on 1
#
# Here we train the methods on 15 datasets and test on one dataset (not seem in the train)

# %%
plt.rcParams.update({'font.size': 14})


n_col = 4
n_row = 2
fig,  axes = plt.subplots(nrows=n_row,  ncols=n_col, figsize=(16, 7))
curr_dataset = ['Occupancy', 'SVDB', 'MITDB', 'Genesis', 'GHL', 'KDD21', 'YAHOO', 'IOPS']

for i, dataset in enumerate(curr_dataset):
    my_colors = list(islice(cycle([methods_colors['avg_ens'],  methods_colors['conv'], methods_colors['conv_2'], methods_colors['sit'], methods_colors['feature_based'], methods_colors['rocket']]), None, len(df_transfer_res[all_method_score].loc[dataset])))
    df_transfer_res[order].loc[dataset].plot(kind='bar', ax=axes[i//n_col, i%n_col], color=my_colors)
    axes[i//n_col, i%n_col].axhline(df_transfer_res['Oracle'].loc[dataset], linestyle='-', color='k')
    axes[i//n_col, i%n_col].axhline(df_transfer_res['best_ad_train'].loc[dataset], linestyle='--', linewidth=2, color=methods_colors['best_ad_train'])
    axes[i//n_col, i%n_col].axhline(df_transfer_res['worst_ad_test'].loc[dataset], linestyle='dashdot', linewidth=2, color=methods_colors['worst_ad_test'])
    axes[i//n_col, i%n_col].set_title(r"Trained on $\bf{all\ but\ " + dataset + "}$" + '\n' + r"Tested on $\bf{" + dataset + "}$" )
    if i//n_col == 1: 
        axes[i//n_col, i%n_col].set_xticks(range(len(all_method_score)), [final_names[x] for x in curr_names], rotation=45)
    else:
        axes[i//n_col, i%n_col].set_xticks([])

plt.tight_layout()
# plt.savefig(figure_path.format("11_one_vs_all_2"))
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupancy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 10
#       7 curr_dataset = ['Occupancy', 'SVDB', 'MITDB', 'Genesis', 'GHL', 'KDD21', 'YAHOO', 'IOPS']
#       9 for i, dataset in enumerate(curr_dataset):
# ---> 10     my_colors = list(islice(cycle([methods_colors['avg_ens'],  methods_colors['conv'], methods_colors['conv_2'], methods_colors['sit'], methods_colors['feature_based'], methods_colors['rocket']]), None, len(df_transfer_res[all_method_score].loc[dataset])))
#      11     df_transfer_res[order].loc[dataset].plot(kind='bar', ax=axes[i//n_col, i%n_col], color=my_colors)
#      12     axes[i//n_col, i%n_col].axhline(df_transfer_res['Oracle'].loc[dataset], linestyle='-', color='k')
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~\Desktop\ChooseWisely\MSAD\venv39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Occupancy'
